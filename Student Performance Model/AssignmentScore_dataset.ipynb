# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(42)

# %%
n = 6607

df = pd.DataFrame({
    'Assignment_Score': np.random.randint(30,100,n)
})

df.to_csv('student_data_assign.csv',index=False)
